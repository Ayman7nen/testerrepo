# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ##  *Ayman Henein Malak*
# ### Data Analyst

# %% [markdown]
# #### *I am interested in Data Science because it is the future*

# %% [markdown]
# ### My code in cell 5 should do some basic calculations

# %%
2*5-5
# Out:
# 5

# %% [markdown]
# - one
# - two
# - three
# | name | age |
# |--------|---------|
# | Ayman | 29 |
# | peter | 34 |
